# %% [markdown]
# # Analysis Template
#
# **Purpose:** Standard template for ad-hoc analysis and research.
# **Author:** [Your Name]
# **Date:** [YYYY-MM-DD]
#
# ## Setup
# This notebook uses the `ml_heating` package directly. No `sys.path` hacks required.

# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime, timedelta

# Standard Library Imports
from src import config
from src.analysis import DataLoader, plotting, model_utils

# Configure Plotting
plt.style.use('seaborn-v0_8-darkgrid')
plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# ## 1. Data Loading
# Use `DataLoader` to fetch data from InfluxDB or CSV. This ensures consistent timestamp handling.

# %%
# Initialize Loader
loader = DataLoader()

# Define Time Range
end_time = datetime.now()
start_time = end_time - timedelta(days=7)

# Fetch Data (Example)
# df = loader.fetch_training_data(
#     start_time=start_time,
#     end_time=end_time,
#     features=['outdoor_temp', 'outlet_temp', 'target_temp']
# )

# print(f"Loaded {len(df)} rows")
# df.head()

# %% [markdown]
# ## 2. Analysis
# Perform your specific analysis here.

# %%
# Your analysis code here

# %% [markdown]
# ## 3. Visualization
# Use `src.analysis.plotting` for consistent visuals.

# %%
# Example Plot
# plotting.plot_prediction_vs_actual(
#     timestamps=df.index,
#     actual=df['outlet_temp'],
#     predicted=df['target_temp'],
#     title="Outlet vs Target Temperature"
# )

# %% [markdown]
# ## 4. Conclusions
# Summarize findings here.
