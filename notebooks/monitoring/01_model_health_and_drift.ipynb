# %% [markdown]
# # Model Health and Drift Monitoring
#
# **Purpose:** Monitor the health of the adaptive learning system, check for parameter drift, and ensure state persistence.
# **Author:** Roo Code
# **Date:** 2026-02-16
#
# ## Setup
# This notebook uses the `ml_heating` package directly.

# %%
# %load_ext autoreload
# %autoreload 2

import sys
import os

# Ensure project root is in path for src imports
project_root = os.path.abspath(os.path.join(os.getcwd(), "../../"))
if project_root not in sys.path:
    sys.path.append(project_root)

import pandas as pd
import matplotlib.pyplot as plt
import json
from datetime import datetime, timedelta, timezone

# Standard Library Imports
from src import config
from src.analysis import DataLoader, plotting
from src.unified_thermal_state import ThermalStateManager

# Configure Plotting
plt.style.use('seaborn-v0_8-darkgrid')
plt.rcParams['figure.figsize'] = (12, 6)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## 1. State Inspection
# Load the current persisted state of the thermal model.

# %%
# Initialize State Manager
state_manager = ThermalStateManager()
state_manager.load_state()
current_state = state_manager.state

print("Current Thermal State:")
print(json.dumps(current_state, indent=2))
# Out:
# Current Thermal State:
# {
#   "metadata": {
#     "version": "1.0",
#     "format": "unified_thermal_state",
#     "created": "2026-02-12T14:38:00.966213",
#     "last_updated": "2026-02-16T13:03:04.133189"
#   },
#   "baseline_parameters": {
#     "thermal_time_constant": 21.59683493331745,
#     "equilibrium_ratio": 0.17,
#     "total_conductance": 0.8,
#     "heat_loss_coefficient": 0.539463110154955,
#     "outlet_effectiveness": 0.4826476925561557,
#     "pv_heat_weight": 0.0005,
#     "fireplace_heat_weight": 5.0,
#     "tv_heat_weight": 0.19130751261040038,
#     "source": "calibrated",
#     "calibration_date": "2026-02-16T10:01:24.081891",
#     "calibration_cycles": 12510
#   },
#   "learning_state": {
#     "cycle_count": 258,
#     "learning_confidence": 5.0,
#     "learning_enabled": true,
#     "parameter_adjustments": {
#       "equilibrium_ratio_delta": 0.0,
#       "total_conductance_delta": 0.0,
#       "heat_loss_coefficient_delta": -0.0023186248369438944,
#       "outlet_effectiveness_delta": 0.0
#     },
#     "parameter_bounds": {
#       "equilibrium_ratio": [
#         0.1,
#         0.9
#       ],
#       "total_conductance": [
#         0.1,
#         0.8
#       ]
#     },
#     "prediction_history": [
#       {
#         "timestamp": null,
#         "predicted": 21.0,
#         "actual": 21.1,
#         "error": 0.10000000000000142,
#         "context": {
#           "outlet_temp": 45.0,
#           "current_indoor": 21.05
#         },
#         "model_internal_prediction": 21.03219090595368,
#         "parameters_at_prediction": {
#           "thermal_time_constant": 21.596281722815004,
#           "heat_loss_coefficient": 0.804956395937751,
#           "outlet_effectiveness": 0.3
#         },
#         "shadow_mode": false,
#         "system_state": "active_mode",
#         "learning_quality": "good",
#         "abs_error": 0.10000000000000142,
#         "squared_error": 0.010000000000000285
#       },
#       {
#         "timestamp": null,
#         "predicted": 21.0,
#         "actual": 21.1,
#         "error": 0.10000000000000142,
#         "context": {
#           "outlet_temp": 45.0,
#           "current_indoor": 21.05
#         },
#         "model_internal_prediction": 21.03219090595368,
#         "parameters_at_prediction": {
#           "thermal_time_constant": 21.596281722815004,
#           "heat_loss_coefficient": 0.804956395937751,
#           "outlet_effectiveness": 0.3
#         },
#         "shadow_mode": false,
#         "system_state": "active_mode",
#         "learning_quality": "good",
#         "abs_error": 0.10000000000000142,
#         "squared_error": 0.010000000000000285
#       },
#       {
#         "timestamp": null,
#         "predicted": 21.0,
#         "actual": 21.1,
#         "error": 0.10000000000000142,
#         "context": {
#           "outlet_temp": 45.0,
#           "current_indoor": 21.05
#         },
#         "model_internal_prediction": 21.03219090595368,
#         "parameters_at_prediction": {
#           "thermal_time_constant": 21.596281722815004,
#           "heat_loss_coefficient": 0.804956395937751,
#           "outlet_effectiveness": 0.3
#         },
#         "shadow_mode": false,
#         "system_state": "active_mode",
#         "learning_quality": "good",
#         "abs_error": 0.10000000000000142,
#         "squared_error": 0.010000000000000285
#       },
#       {
#         "timestamp": null,
#         "predicted": 22.0,
#         "actual": 20.0,
#         "error": -2.0,
#         "context": {
#           "outlet_temp": 50.0,
#           "outdoor_temp": 5.0,
#           "current_indoor": 20.0,
#           "target_temp": 22.0
#         },
#         "model_internal_prediction": 19.967978160791475,
#         "parameters_at_prediction": {
#           "thermal_time_constant": 21.59683493331745,
#           "heat_loss_coefficient": 0.804956395937751,
#           "outlet_effectiveness": 0.3
#         },
#         "shadow_mode": false,
#         "system_state": "active_mode",
#         "learning_quality": "fair",
#         "abs_error": 2.0,
#         "squared_error": 4.0
#       },
#       {
#         "timestamp": null,
#         "predicted": 22.0,
#         "actual": 20.0,
#         "error": -2.0,
#         "context": {
#           "outlet_temp": 49.0,
#           "outdoor_temp": 5.0,
#           "current_indoor": 20.0,
#           "target_temp": 22.0
#         },
#         "model_internal_prediction": 19.963489737483588,
#         "parameters_at_prediction": {
#           "thermal_time_constant": 21.59670563454411,
#           "heat_loss_coefficient": 0.8160238631641218,
#           "outlet_effectiveness": 0.3
#         },
#         "shadow_mode": false,
#         "system_state": "active_mode",
#         "learning_quality": "fair",
#         "abs_error": 2.0,
#         "squared_error": 4.0
#       },
#       {
#         "timestamp": null,
#         "predicted": 22.0,
#         "actual": 20.0,
#         "error": -2.0,
#         "context": {
#           "outlet_temp": 48.0,
#           "outdoor_temp": 5.0,
#           "current_indoor": 20.0,
#           "target_temp": 22.0
#         },
#         "model_internal_prediction": 19.959557055879536,
#         "parameters_at_prediction": {
#           "thermal_time_constant": 21.596612457692522,
#           "heat_loss_coefficient": 0.8231047133416712,
#           "outlet_effectiveness": 0.3
#         },
#         "shadow_mode": false,
#         "system_state": "active_mode",
#         "learning_quality": "fair",
#         "abs_error": 2.0,
#         "squared_error": 4.0
#       },
#       {
#         "timestamp": null,
#         "predicted": 22.0,
#         "actual": 20.0,
#         "error": -2.0,
#         "context": {
#           "outlet_temp": 47.0,
#           "outdoor_temp": 5.0,
#           "current_indoor": 20.0,
#           "target_temp": 22.0
#         },
#         "model_internal_prediction": 19.956012258058003,
#         "parameters_at_prediction": {
#           "thermal_time_constant": 21.596553302816172,
#           "heat_loss_coefficient": 0.8272112218904532,
#           "outlet_effectiveness": 0.3
#         },
#         "shadow_mode": false,
#         "system_state": "active_mode",
#         "learning_quality": "fair",
#         "abs_error": 2.0,
#         "squared_error": 4.0
#       },
#       {
#         "timestamp": null,
#         "predicted": 22.0,
#         "actual": 20.0,
#         "error": -2.0,
#         "context": {
#           "outlet_temp": 46.0,
#           "outdoor_temp": 5.0,
#           "current_indoor": 20.0,
#           "target_temp": 22.0
#         },
#         "model_internal_prediction": 19.952506053979718,
#         "parameters_at_prediction": {
#           "thermal_time_constant": 21.59649156665647,
#           "heat_loss_coefficient": 0.8312012459889584,
#           "outlet_effectiveness": 0.3
#         },
#         "shadow_mode": false,
#         "system_state": "active_mode",
#         "learning_quality": "fair",
#         "abs_error": 2.0,
#         "squared_error": 4.0
#       },
#       {
#         "timestamp": null,
#         "predicted": 22.0,
#         "actual": 20.0,
#         "error": -2.0,
#         "context": {
#           "outlet_temp": 45.0,
#           "outdoor_temp": 5.0,
#           "current_indoor": 20.0,
#           "target_temp": 22.0
#         },
#         "model_internal_prediction": 19.94903656033539,
#         "parameters_at_prediction": {
#           "thermal_time_constant": 21.596427350472844,
#           "heat_loss_coefficient": 0.835078479376397,
#           "outlet_effectiveness": 0.3
#         },
#         "shadow_mode": false,
#         "system_state": "active_mode",
#         "learning_quality": "fair",
#         "abs_error": 2.0,
#         "squared_error": 4.0
#       },
#       {
#         "timestamp": null,
#         "predicted": 22.0,
#         "actual": 20.0,
#         "error": -2.0,
#         "context": {
#           "outlet_temp": 44.0,
#           "outdoor_temp": 5.0,
#           "current_indoor": 20.0,
#           "target_temp": 22.0
#         },
#         "model_internal_prediction": 19.945602004818102,
#         "parameters_at_prediction": {
#           "thermal_time_constant": 21.59636075127254,
#           "heat_loss_coefficient": 0.8388464439349956,
#           "outlet_effectiveness": 0.3
#         },
#         "shadow_mode": false,
#         "system_state": "active_mode",
#         "learning_quality": "fair",
#         "abs_error": 2.0,
#         "squared_error": 4.0
#       },
#       {
#         "timestamp": null,
#         "predicted": 22.0,
#         "actual": 20.0,
#         "error": -2.0,
#         "context": {
#           "outlet_temp": 43.0,
#           "outdoor_temp": 5.0,
#           "current_indoor": 20.0,
#           "target_temp": 22.0
#         },
#         "model_internal_prediction": 19.942200717683924,
#         "parameters_at_prediction": {
#           "thermal_time_constant": 21.596291862051622,
#           "heat_loss_coefficient": 0.8425085007621328,
#           "outlet_effectiveness": 0.3
#         },
#         "shadow_mode": false,
#         "system_state": "active_mode",
#         "learning_quality": "fair",
#         "abs_error": 2.0,
#         "squared_error": 4.0
#       },
#       {
#         "timestamp": null,
#         "predicted": 22.0,
#         "actual": 20.0,
#         "error": -2.0,
#         "context": {
#           "outlet_temp": 42.0,
#           "outdoor_temp": 5.0,
#           "current_indoor": 20.0,
#           "target_temp": 22.0
#         },
#         "model_internal_prediction": 19.9388311240938,
#         "parameters_at_prediction": {
#           "thermal_time_constant": 21.596220772018103,
#           "heat_loss_coefficient": 0.8460678603387665,
#           "outlet_effectiveness": 0.3
#         },
#         "shadow_mode": false,
#         "system_state": "active_mode",
#         "learning_quality": "fair",
#         "abs_error": 2.0,
#         "squared_error": 4.0
#       },
#       {
#         "timestamp": null,
#         "predicted": 22.0,
#         "actual": 20.0,
#         "error": -2.0,
#         "context": {
#           "outlet_temp": 41.0,
#           "outdoor_temp": 5.0,
#           "current_indoor": 20.0,
#           "target_temp": 22.0
#         },
#         "model_internal_prediction": 19.935491737152063,
#         "parameters_at_prediction": {
#           "thermal_time_constant": 21.596147566798923,
#           "heat_loss_coefficient": 0.8495275918826342,
#           "outlet_effectiveness": 0.3
#         },
#         "shadow_mode": false,
#         "system_state": "active_mode",
#         "learning_quality": "fair",
#         "abs_error": 2.0,
#         "squared_error": 4.0
#       },
#       {
#         "timestamp": "2026-02-15T16:26:35.848395",
#         "predicted": 21.1,
#         "actual": 21.0,
#         "error": -0.10000000000000142,
#         "abs_error": 0.10000000000000142,
#         "squared_error": 0.010000000000000285,
#         "context": {
#           "outlet_temp": 45.0
#         }
#       },
#       {
#         "timestamp": "2026-02-15T16:26:35.855795",
#         "predicted": 20.9,
#         "actual": 21.0,
#         "error": 0.10000000000000142,
#         "abs_error": 0.10000000000000142,
#         "squared_error": 0.010000000000000285,
#         "context": {
#           "outlet_temp": 47.0
#         }
#       },
#       {
#         "timestamp": "2026-02-15T16:26:35.863111",
#         "predicted": 21.2,
#         "actual": 21.0,
#         "error": -0.1999999999999993,
#         "abs_error": 0.1999999999999993,
#         "squared_error": 0.039999999999999716,
#         "context": {
#           "outlet_temp": 43.0
#         }
#       },
#       {
#         "timestamp": "2026-02-15T16:26:35.951523",
#         "predicted": 21.0,
#         "actual": 20.8,
#         "error": -0.1999999999999993,
#         "abs_error": 0.1999999999999993,
#         "squared_error": 0.039999999999999716,
#         "context": {
#           "indoor_temp_lag_30m": 20.0,
#           "target_temp": 21.0,
#           "outdoor_temp": 10.0,
#           "pv_now": 500.0,
#           "fireplace_on": 0,
#           "tv_on": 1
#         }
#       },
#       {
#         "timestamp": "2026-02-15T16:26:35.959121",
#         "predicted": 21.0,
#         "actual": 20.8,
#         "error": -0.1999999999999993,
#         "context": {
#           "indoor_temp_lag_30m": 20.0,
#           "target_temp": 21.0,
#           "outdoor_temp": 10.0,
#           "pv_now": 500.0,
#           "fireplace_on": 0,
#           "tv_on": 1
#         },
#         "abs_error": 0.1999999999999993,
#         "squared_error": 0.039999999999999716
#       },
#       {
#         "timestamp": null,
#         "predicted": 21.0,
#         "actual": 21.1,
#         "error": 0.10000000000000142,
#         "context": {
#           "outlet_temp": 45.0,
#           "current_indoor": 21.05
#         },
#         "model_internal_prediction": 21.02891588667989,
#         "parameters_at_prediction": {
#           "thermal_time_constant": 21.59683493331745,
#           "heat_loss_coefficient": 0.8637758704990206,
#           "outlet_effectiveness": 0.30883288844845275
#         },
#         "shadow_mode": false,
#         "system_state": "active_mode",
#         "learning_quality": "good",
#         "abs_error": 0.10000000000000142,
#         "squared_error": 0.010000000000000285
#       },
#       {
#         "timestamp": null,
#         "predicted": 21.0,
#         "actual": 21.1,
#         "error": 0.10000000000000142,
#         "context": {
#           "outlet_temp": 45.0,
#           "current_indoor": 21.05
#         },
#         "model_internal_prediction": 21.027361157412486,
#         "parameters_at_prediction": {
#           "thermal_time_constant": 21.596780177654438,
#           "heat_loss_coefficient": 0.8657146352411524,
#           "outlet_effectiveness": 0.30340057176146124
#         },
#         "shadow_mode": false,
#         "system_state": "active_mode",
#         "learning_quality": "good",
#         "abs_error": 0.10000000000000142,
#         "squared_error": 0.010000000000000285
#       },
#       {
#         "timestamp": null,
#         "predicted": 21.0,
#         "actual": 21.1,
#         "error": 0.10000000000000142,
#         "context": {
#           "outlet_temp": 45.0,
#           "current_indoor": 21.05
#         },
#         "model_internal_prediction": 21.02632311262476,
#         "parameters_at_prediction": {
#           "thermal_time_constant": 21.59672248821809,
#           "heat_loss_coefficient": 0.867605154960681,
#           "outlet_effectiveness": 0.3
#         },
#         "shadow_mode": false,
#         "system_state": "active_mode",
#         "learning_quality": "good",
#         "abs_error": 0.10000000000000142,
#         "squared_error": 0.010000000000000285
#       },
#       {
#         "timestamp": null,
#         "predicted": 21.0,
#         "actual": 21.1,
#         "error": 0.10000000000000142,
#         "context": {
#           "outlet_temp": 45.0,
#           "current_indoor": 21.05
#         },
#         "model_internal_prediction": 21.026159420774032,
#         "parameters_at_prediction": {
#           "thermal_time_constant": 21.59666240656968,
#           "heat_loss_coefficient": 0.8694540020654805,
#           "outlet_effectiveness": 0.3
#         },
#         "shadow_mode": false,
#         "system_state": "active_mode",
#         "learning_quality": "good",
#         "abs_error": 0.10000000000000142,
#         "squared_error": 0.010000000000000285
#       },
#       {
#         "timestamp": null,
#         "predicted": 21.0,
#         "actual": 21.1,
#         "error": 0.10000000000000142,
#         "context": {
#           "outlet_temp": 45.0,
#           "current_indoor": 21.05
#         },
#         "model_internal_prediction": 21.025998980850407,
#         "parameters_at_prediction": {
#           "thermal_time_constant": 21.59660079533043,
#           "heat_loss_coefficient": 0.8712717661922574,
#           "outlet_effectiveness": 0.3
#         },
#         "shadow_mode": false,
#         "system_state": "active_mode",
#         "learning_quality": "good",
#         "abs_error": 0.10000000000000142,
#         "squared_error": 0.010000000000000285
#       },
#       {
#         "timestamp": null,
#         "predicted": 21.0,
#         "actual": 21.1,
#         "error": 0.10000000000000142,
#         "context": {
#           "outlet_temp": 45.0,
#           "current_indoor": 21.05
#         },
#         "model_internal_prediction": 21.025998980850407,
#         "parameters_at_prediction": {
#           "thermal_time_constant": 21.59660079533043,
#           "heat_loss_coefficient": 0.8712717661922574,
#           "outlet_effectiveness": 0.3
#         },
#         "shadow_mode": false,
#         "system_state": "active_mode",
#         "learning_quality": "good",
#         "abs_error": 0.10000000000000142,
#         "squared_error": 0.010000000000000285
#       },
#       {
#         "timestamp": null,
#         "predicted": 21.0,
#         "actual": 21.1,
#         "error": 0.10000000000000142,
#         "context": {
#           "outlet_temp": 45.0,
#           "current_indoor": 21.05
#         },
#         "model_internal_prediction": 21.025998980850407,
#         "parameters_at_prediction": {
#           "thermal_time_constant": 21.59660079533043,
#           "heat_loss_coefficient": 0.8712717661922574,
#           "outlet_effectiveness": 0.3
#         },
#         "shadow_mode": false,
#         "system_state": "active_mode",
#         "learning_quality": "good",
#         "abs_error": 0.10000000000000142,
#         "squared_error": 0.010000000000000285
#       },
#       {
#         "timestamp": null,
#         "predicted": 21.0,
#         "actual": 21.1,
#         "error": 0.10000000000000142,
#         "context": {
#           "outlet_temp": 45.0,
#           "current_indoor": 21.05
#         },
#         "model_internal_prediction": 21.025998980850407,
#         "parameters_at_prediction": {
#           "thermal_time_constant": 21.59660079533043,
#           "heat_loss_coefficient": 0.8712717661922574,
#           "outlet_effectiveness": 0.3
#         },
#         "shadow_mode": false,
#         "system_state": "active_mode",
#         "learning_quality": "good",
#         "abs_error": 0.10000000000000142,
#         "squared_error": 0.010000000000000285
#       },
#       {
#         "timestamp": null,
#         "predicted": 21.0,
#         "actual": 21.1,
#         "error": 0.10000000000000142,
#         "context": {
#           "outlet_temp": 45.0,
#           "current_indoor": 21.05
#         },
#         "model_internal_prediction": 21.025998980850407,
#         "parameters_at_prediction": {
#           "thermal_time_constant": 21.59660079533043,
#           "heat_loss_coefficient": 0.8712717661922574,
#           "outlet_effectiveness": 0.3
#         },
#         "shadow_mode": false,
#         "system_state": "active_mode",
#         "learning_quality": "good",
#         "abs_error": 0.10000000000000142,
#         "squared_error": 0.010000000000000285
#       },
#       {
#         "timestamp": null,
#         "predicted": 21.0,
#         "actual": 21.1,
#         "error": 0.10000000000000142,
#         "context": {
#           "outlet_temp": 45.0,
#           "current_indoor": 21.05
#         },
#         "model_internal_prediction": 21.025998980850407,
#         "parameters_at_prediction": {
#           "thermal_time_constant": 21.59660079533043,
#           "heat_loss_coefficient": 0.8712717661922574,
#           "outlet_effectiveness": 0.3
#         },
#         "shadow_mode": false,
#         "system_state": "active_mode",
#         "learning_quality": "good",
#         "abs_error": 0.10000000000000142,
#         "squared_error": 0.010000000000000285
#       },
#       {
#         "timestamp": null,
#         "predicted": 22.0,
#         "actual": 20.0,
#         "error": -2.0,
#         "context": {
#           "outlet_temp": 50.0,
#           "outdoor_temp": 5.0,
#           "current_indoor": 20.0,
#           "target_temp": 22.0
#         },
#         "model_internal_prediction": 19.9600168637067,
#         "parameters_at_prediction": {
#           "thermal_time_constant": 21.59683493331745,
#           "heat_loss_coefficient": 0.8712717661922574,
#           "outlet_effectiveness": 0.3
#         },
#         "shadow_mode": false,
#         "system_state": "active_mode",
#         "learning_quality": "fair",
#         "abs_error": 2.0,
#         "squared_error": 4.0
#       },
#       {
#         "timestamp": null,
#         "predicted": 22.0,
#         "actual": 20.0,
#         "error": -2.0,
#         "context": {
#           "outlet_temp": 49.0,
#           "outdoor_temp": 5.0,
#           "current_indoor": 20.0,
#           "target_temp": 22.0
#         },
#         "model_internal_prediction": 19.956818607873508,
#         "parameters_at_prediction": {
#           "thermal_time_constant": 21.596797805638527,
#           "heat_loss_coefficient": 0.8735369059721939,
#           "outlet_effectiveness": 0.3
#         },
#         "shadow_mode": false,
#         "system_state": "active_mode",
#         "learning_quality": "fair",
#         "abs_error": 2.0,
#         "squared_error": 4.0
#       },
#       {
#         "timestamp": null,
#         "predicted": 22.0,
#         "actual": 20.0,
#         "error": -2.0,
#         "context": {
#           "outlet_temp": 48.0,
#           "outdoor_temp": 5.0,
#           "current_indoor": 20.0,
#           "target_temp": 22.0
#         },
#         "model_internal_prediction": 19.953636290311586,
#         "parameters_at_prediction": {
#           "thermal_time_constant": 21.596759074057935,
#           "heat_loss_coefficient": 0.8757682424291132,
#           "outlet_effectiveness": 0.3
#         },
#         "shadow_mode": false,
#         "system_state": "active_mode",
#         "learning_quality": "fair",
#         "abs_error": 2.0,
#         "squared_error": 4.0
#       },
#       {
#         "timestamp": null,
#         "predicted": 22.0,
#         "actual": 20.0,
#         "error": -2.0,
#         "context": {
#           "outlet_temp": 47.0,
#           "outdoor_temp": 5.0,
#           "current_indoor": 20.0,
#           "target_temp": 22.0
#         },
#         "model_internal_prediction": 19.950469507157816,
#         "parameters_at_prediction": {
#           "thermal_time_constant": 21.59671874818722,
#           "heat_loss_coefficient": 0.8779661454400605,
#           "outlet_effectiveness": 0.3
#         },
#         "shadow_mode": false,
#         "system_state": "active_mode",
#         "learning_quality": "fair",
#         "abs_error": 2.0,
#         "squared_error": 4.0
#       },
#       {
#         "timestamp": null,
#         "predicted": 22.0,
#         "actual": 20.0,
#         "error": -2.0,
#         "context": {
#           "outlet_temp": 46.0,
#           "outdoor_temp": 5.0,
#           "current_indoor": 20.0,
#           "target_temp": 22.0
#         },
#         "model_internal_prediction": 19.947317865210106,
#         "parameters_at_prediction": {
#           "thermal_time_constant": 21.596676837408236,
#           "heat_loss_coefficient": 0.8801309750259205,
#           "outlet_effectiveness": 0.3
#         },
#         "shadow_mode": false,
#         "system_state": "active_mode",
#         "learning_quality": "fair",
#         "abs_error": 2.0,
#         "squared_error": 4.0
#       },
#       {
#         "timestamp": null,
#         "predicted": 22.0,
#         "actual": 20.0,
#         "error": -2.0,
#         "context": {
#           "outlet_temp": 45.0,
#           "outdoor_temp": 5.0,
#           "current_indoor": 20.0,
#           "target_temp": 22.0
#         },
#         "model_internal_prediction": 19.94418098150813,
#         "parameters_at_prediction": {
#           "thermal_time_constant": 21.59663335087942,
#           "heat_loss_coefficient": 0.8822630816609487,
#           "outlet_effectiveness": 0.3
#         },
#         "shadow_mode": false,
#         "system_state": "active_mode",
#         "learning_quality": "fair",
#         "abs_error": 2.0,
#         "squared_error": 4.0
#       },
#       {
#         "timestamp": null,
#         "predicted": 22.0,
#         "actual": 20.0,
#         "error": -2.0,
#         "context": {
#           "outlet_temp": 44.0,
#           "outdoor_temp": 5.0,
#           "current_indoor": 20.0,
#           "target_temp": 22.0
#         },
#         "model_internal_prediction": 19.941058482933435,
#         "parameters_at_prediction": {
#           "thermal_time_constant": 21.59658829754185,
#           "heat_loss_coefficient": 0.8843628065692717,
#           "outlet_effectiveness": 0.3
#         },
#         "shadow_mode": false,
#         "system_state": "active_mode",
#         "learning_quality": "fair",
#         "abs_error": 2.0,
#         "squared_error": 4.0
#       },
#       {
#         "timestamp": null,
#         "predicted": 22.0,
#         "actual": 20.0,
#         "error": -2.0,
#         "context": {
#           "outlet_temp": 43.0,
#           "outdoor_temp": 5.0,
#           "current_indoor": 20.0,
#           "target_temp": 22.0
#         },
#         "model_internal_prediction": 19.93795000582773,
#         "parameters_at_prediction": {
#           "thermal_time_constant": 21.596541686125068,
#           "heat_loss_coefficient": 0.8864304820089578,
#           "outlet_effectiveness": 0.3
#         },
#         "shadow_mode": false,
#         "system_state": "active_mode",
#         "learning_quality": "fair",
#         "abs_error": 2.0,
#         "squared_error": 4.0
#       },
#       {
#         "timestamp": null,
#         "predicted": 22.0,
#         "actual": 20.0,
#         "error": -2.0,
#         "context": {
#           "outlet_temp": 42.0,
#           "outdoor_temp": 5.0,
#           "current_indoor": 20.0,
#           "target_temp": 22.0
#         },
#         "model_internal_prediction": 19.934855195628415,
#         "parameters_at_prediction": {
#           "thermal_time_constant": 21.596493525152663,
#           "heat_loss_coefficient": 0.8884664315443026,
#           "outlet_effectiveness": 0.3
#         },
#         "shadow_mode": false,
#         "system_state": "active_mode",
#         "learning_quality": "fair",
#         "abs_error": 2.0,
#         "squared_error": 4.0
#       },
#       {
#         "timestamp": null,
#         "predicted": 22.0,
#         "actual": 20.0,
#         "error": -2.0,
#         "context": {
#           "outlet_temp": 41.0,
#           "outdoor_temp": 5.0,
#           "current_indoor": 20.0,
#           "target_temp": 22.0
#         },
#         "model_internal_prediction": 19.931773706520403,
#         "parameters_at_prediction": {
#           "thermal_time_constant": 21.596443822947652,
#           "heat_loss_coefficient": 0.8904709703069074,
#           "outlet_effectiveness": 0.3
#         },
#         "shadow_mode": false,
#         "system_state": "active_mode",
#         "learning_quality": "fair",
#         "abs_error": 2.0,
#         "squared_error": 4.0
#       },
#       {
#         "timestamp": "2026-02-15T16:26:52.520208",
#         "predicted": 21.1,
#         "actual": 21.0,
#         "error": -0.10000000000000142,
#         "abs_error": 0.10000000000000142,
#         "squared_error": 0.010000000000000285,
#         "context": {
#           "outlet_temp": 45.0
#         }
#       },
#       {
#         "timestamp": "2026-02-15T16:26

#         "context": {
#           "outlet_temp": 49.0,
#           "outdoor_temp": -4.033333333333333,
#           "pv_power": 0.0,
#           "fireplace_on": 0.0,
#           "tv_on": 0.0,
#           "current_indoor": 21.4,
#           "thermal_power": 11.419407999999995,
#           "auxiliary_heat": 0.0,
#           "learning_mode": "active_mode_ml_trajectory",
#           "was_shadow_mode_cycle": false,
#           "ml_calculated_temp": 48.96997600043059,
#           "hc_applied_temp": 49.0
#         }
#       },
#       {
#         "timestamp": "2026-02-16T02:02:03.898528",
#         "predicted": 21.3,
#         "actual": 21.4,
#         "error": 0.09999999999999787,
#         "abs_error": 0.09999999999999787,
#         "squared_error": 0.009999999999999573,
#         "context": {
#           "outlet_temp": 49.0,
#           "outdoor_temp": -3.84,
#           "pv_power": 0.0,
#           "fireplace_on": 0.0,
#           "tv_on": 0.0,
#           "current_indoor": 21.3,
#           "thermal_power": 11.076155999999997,
#           "auxiliary_heat": 0.0,
#           "learning_mode": "active_mode_ml_trajectory",
#           "was_shadow_mode_cycle": false,
#           "ml_calculated_temp": 49.0625,
#           "hc_applied_temp": 49.0
#         }
#       },
#       {
#         "timestamp": "2026-02-16T02:20:04.237249",
#         "predicted": 21.3,
#         "actual": 21.4,
#         "error": 0.09999999999999787,
#         "abs_error": 0.09999999999999787,
#         "squared_error": 0.009999999999999573,
#         "context": {
#           "outlet_temp": 46.0,
#           "outdoor_temp": -3.84,
#           "pv_power": 0.0,
#           "fireplace_on": 0.0,
#           "tv_on": 0.0,
#           "current_indoor": 21.3,
#           "thermal_power": 11.076155999999997,
#           "auxiliary_heat": 0.0,
#           "learning_mode": "active_mode_ml_trajectory",
#           "was_shadow_mode_cycle": false,
#           "ml_calculated_temp": 49.0625,
#           "hc_applied_temp": 46.0
#         }
#       },
#       {
#         "timestamp": "2026-02-16T02:50:04.798305",
#         "predicted": 21.4,
#         "actual": 21.4,
#         "error": 0.0,
#         "abs_error": 0.0,
#         "squared_error": 0.0,
#         "context": {
#           "outlet_temp": 45.0,
#           "outdoor_temp": -3.62,
#           "pv_power": 0.0,
#           "fireplace_on": 0.0,
#           "tv_on": 0.0,
#           "current_indoor": 21.4,
#           "thermal_power": 6.383649999999999,
#           "auxiliary_heat": 0.0,
#           "learning_mode": "active_mode_ml_trajectory",
#           "was_shadow_mode_cycle": false,
#           "ml_calculated_temp": 45.83050805774957,
#           "hc_applied_temp": 45.0
#         }
#       },
#       {
#         "timestamp": "2026-02-16T03:12:05.161308",
#         "predicted": 21.4,
#         "actual": 21.3,
#         "error": -0.09999999999999787,
#         "abs_error": 0.09999999999999787,
#         "squared_error": 0.009999999999999573,
#         "context": {
#           "outlet_temp": 45.0,
#           "outdoor_temp": -3.4066666666666667,
#           "pv_power": 0.0,
#           "fireplace_on": 0.0,
#           "tv_on": 0.0,
#           "current_indoor": 21.4,
#           "thermal_power": 7.137967199999997,
#           "auxiliary_heat": 0.0,
#           "learning_mode": "active_mode_ml_trajectory",
#           "was_shadow_mode_cycle": false,
#           "ml_calculated_temp": 45.82978754552028,
#           "hc_applied_temp": 45.0
#         }
#       },
#       {
#         "timestamp": "2026-02-16T03:30:05.508499",
#         "predicted": 21.4,
#         "actual": 21.3,
#         "error": -0.09999999999999787,
#         "abs_error": 0.09999999999999787,
#         "squared_error": 0.009999999999999573,
#         "context": {
#           "outlet_temp": 49.0,
# ...
#         "avg_recent_error": 0.39000000000000024,
#         "gradients": {
#           "thermal": -0.00040425521216911974,
#           "heat_loss_coefficient": 0.10847411687256527,
#           "outlet_effectiveness": -0.12678737332627016,
#           "pv_heat_weight": -6.712131978641115,
#           "tv_heat_weight": -0.008390164973296319
#         },
#         "changes": {
#           "thermal": 2.74200875693964e-05,
#           "heat_loss_coefficient": 0.007357653517646834,
#           "outlet_effectiveness": 0.008599817083029593,
#           "pv_heat_weight": 0.0,
#           "tv_heat_weight": 0.0005690936106161892
#         }
#       },
#       {
#         "timestamp": null,
#         "thermal_time_constant": 21.59723507865624,
#         "heat_loss_coefficient": 0.6585992718242024,
#         "outlet_effectiveness": 0.3163409020411776,
#         "pv_heat_weight": 0.005,
#         "tv_heat_weight": 0.19525902213994312,
#         "learning_rate": 0.06782865562566033,
#         "learning_confidence": 4.521910375044022,
#         "avg_recent_error": 0.43000000000000005,
#         "gradients": {
#           "thermal": 0.000156910502807861,
#           "heat_loss_coefficient": 0.12080115898633892,
#           "outlet_effectiveness": -0.11412705864126682,
#           "pv_heat_weight": -8.798443054573113,
#           "tv_heat_weight": -0.007332035878804266
#         },
#         "changes": {
#           "thermal": 1.0643028460322057e-05,
#           "heat_loss_coefficient": 0.008193780212065072,
#           "outlet_effectiveness": 0.0077410849581480146,
#           "pv_heat_weight": 0.0,
#           "tv_heat_weight": 0.0004973221366584013
#         }
#       },
#       {
#         "timestamp": null,
#         "thermal_time_constant": 21.597193546295134,
#         "heat_loss_coefficient": 0.6497152103137636,
#         "outlet_effectiveness": 0.3233973394782887,
#         "pv_heat_weight": 0.005,
#         "tv_heat_weight": 0.19570129174106868,
#         "learning_rate": 0.06782865562566033,
#         "learning_confidence": 4.521910375044022,
#         "avg_recent_error": 0.4699999999999999,
#         "gradients": {
#           "thermal": 0.0006123129040752752,
#           "heat_loss_coefficient": 0.1309779978460589,
#           "outlet_effectiveness": -0.10403327873774909,
#           "pv_heat_weight": -10.43263138968421,
#           "tv_heat_weight": -0.006520394618557567
#         },
#         "changes": {
#           "thermal": 4.15323611058227e-05,
#           "heat_loss_coefficient": 0.008884061510438857,
#           "outlet_effectiveness": 0.007056437437111096,
#           "pv_heat_weight": 0.0,
#           "tv_heat_weight": 0.00044226960112556113
#         }
#       },
#       {
#         "timestamp": null,
#         "thermal_time_constant": 21.59712600750498,
#         "heat_loss_coefficient": 0.6402354078585115,
#         "outlet_effectiveness": 0.32988655809242945,
#         "pv_heat_weight": 0.005,
#         "tv_heat_weight": 0.19610008271276502,
#         "learning_rate": 0.06782865562566033,
#         "learning_confidence": 4.521910375044022,
#         "avg_recent_error": 0.5,
#         "gradients": {
#           "thermal": 0.0009957265042404018,
#           "heat_loss_coefficient": 0.1397610253042636,
#           "outlet_effectiveness": -0.0956707538175916,
#           "pv_heat_weight": -11.75877563892147,
#           "tv_heat_weight": -0.0058793878194673965
#         },
#         "changes": {
#           "thermal": 6.753879015519715e-05,
#           "heat_loss_coefficient": 0.00947980245525204,
#           "outlet_effectiveness": 0.006489218614140757,
#           "pv_heat_weight": 0.0,
#           "tv_heat_weight": 0.0003987909716963445
#         }
#       },
#       {
#         "timestamp": "2026-02-16T09:58:39.893794",
#         "thermal_time_constant": 21.5968508057055,
#         "heat_loss_coefficient": 0.6581915456926044,
#         "outlet_effectiveness": 0.30988655809242943,
#         "pv_heat_weight": 0.0005,
#         "tv_heat_weight": 0.19124720072613416,
#         "learning_rate": 0.04974101412548424,
#         "learning_confidence": 4.974101412548424,
#         "avg_recent_error": 0.3100000000000005,
#         "gradients": {
#           "thermal": -0.00031910061202466977,
#           "heat_loss_coefficient": -0.36099259634703174,
#           "outlet_effectiveness": 0.7024525705863027,
#           "pv_heat_weight": 0.0,
#           "tv_heat_weight": 0.0
#         },
#         "changes": {
#           "thermal": 1.58723880510081e-05,
#           "heat_loss_coefficient": 0.01795613783409289,
#           "outlet_effectiveness": 0.020000000000000018,
#           "pv_heat_weight": 0.0,
#           "tv_heat_weight": 0.0
#         }
#       },
#       {
#         "timestamp": "2026-02-16T09:59:05.128232",
#         "thermal_time_constant": 21.596819213424926,
#         "heat_loss_coefficient": 0.6667050498592939,
#         "outlet_effectiveness": 0.3,
#         "pv_heat_weight": 0.0005,
#         "tv_heat_weight": 0.19124720072613416,
#         "learning_rate": 0.05,
#         "learning_confidence": 5.0,
#         "avg_recent_error": 0.2900000000000002,
#         "gradients": {
#           "thermal": 0.0003143978504698275,
#           "heat_loss_coefficient": -0.17027008333379,
#           "outlet_effectiveness": 0.36260717426422673,
#           "pv_heat_weight": 0.0,
#           "tv_heat_weight": 0.0
#         },
#         "changes": {
#           "thermal": 1.5719892523691215e-05,
#           "heat_loss_coefficient": 0.0085135041666895,
#           "outlet_effectiveness": 0.009886558092429443,
#           "pv_heat_weight": 0.0,
#           "tv_heat_weight": 0.0
#         }
#       },
#       {
#         "timestamp": "2026-02-16T10:01:31.039439",
#         "thermal_time_constant": 21.59683493331745,
#         "heat_loss_coefficient": 0.539463110154955,
#         "outlet_effectiveness": 0.4826476925561557,
#         "pv_heat_weight": 0.0005,
#         "tv_heat_weight": 0.19130751261040038,
#         "learning_rate": 0.0033000000000000004,
#         "learning_confidence": 3.3000000000000003,
#         "avg_recent_error": 0.08000000000000007,
#         "gradients": {
#           "thermal": 0.0,
#           "heat_loss_coefficient": 0.0,
#           "outlet_effectiveness": 0.0,
#           "pv_heat_weight": 0.0,
#           "tv_heat_weight": 0.0
#         },
#         "changes": {
#           "thermal": 0.0,
#           "heat_loss_coefficient": 0.0,
#           "outlet_effectiveness": 0.0,
#           "pv_heat_weight": 0.0,
#           "tv_heat_weight": 0.0
#         }
#       },
#       {
#         "timestamp": "2026-02-16T10:18:31.340427",
#         "thermal_time_constant": 21.59683493331745,
#         "heat_loss_coefficient": 0.539463110154955,
#         "outlet_effectiveness": 0.4826476925561557,
#         "pv_heat_weight": 0.0005,
#         "tv_heat_weight": 0.19130751261040038,
#         "learning_rate": 0.00036300000000000004,
#         "learning_confidence": 3.630000000000001,
#         "avg_recent_error": 0.06999999999999992,
#         "gradients": {
#           "thermal": 0.0,
#           "heat_loss_coefficient": 0.0,
#           "outlet_effectiveness": 0.0,
#           "pv_heat_weight": 0.0,
#           "tv_heat_weight": 0.0
#         },
#         "changes": {
#           "thermal": 0.0,
#           "heat_loss_coefficient": 0.0,
#           "outlet_effectiveness": 0.0,
#           "pv_heat_weight": 0.0,
#           "tv_heat_weight": 0.0
#         }
#       },
#       {
#         "timestamp": "2026-02-16T10:36:31.695045",
#         "thermal_time_constant": 21.596834918182797,
#         "heat_loss_coefficient": 0.5394678749642766,
#         "outlet_effectiveness": 0.4826476925561557,
#         "pv_heat_weight": 0.0001398184348310403,
#         "tv_heat_weight": 0.19130751261040038,
#         "learning_rate": 0.00039930000000000016,
#         "learning_confidence": 3.993000000000001,
#         "avg_recent_error": 0.06999999999999992,
#         "gradients": {
#           "thermal": 3.7902957584762e-05,
#           "heat_loss_coefficient": -0.011932905889575166,
#           "outlet_effectiveness": 0.0,
#           "pv_heat_weight": 0.9020324697444516,
#           "tv_heat_weight": 0.0
#         },
#         "changes": {
#           "thermal": 1.5134652642245783e-08,
#           "heat_loss_coefficient": 4.764809321655683e-06,
#           "outlet_effectiveness": 0.0,
#           "pv_heat_weight": 0.0003601815651689597,
#           "tv_heat_weight": 0.0
#         }
#       },
#       {
#         "timestamp": "2026-02-16T11:06:32.145581",
#         "thermal_time_constant": 21.596832885047853,
#         "heat_loss_coefficient": 0.5399033318604562,
#         "outlet_effectiveness": 0.4826476925561557,
#         "pv_heat_weight": 0.0001,
#         "tv_heat_weight": 0.19130751261040038,
#         "learning_rate": 0.04392300000000002,
#         "learning_confidence": 4.392300000000001,
#         "avg_recent_error": 0.05,
#         "gradients": {
#           "thermal": 4.62886174603112e-05,
#           "heat_loss_coefficient": -0.009914097310739363,
#           "outlet_effectiveness": 0.0,
#           "pv_heat_weight": 0.7892714403310853,
#           "tv_heat_weight": 0.0
#         },
#         "changes": {
#           "thermal": 2.0331349439572932e-06,
#           "heat_loss_coefficient": 0.00043545689617963124,
#           "outlet_effectiveness": 0.0,
#           "pv_heat_weight": 3.9818434831040306e-05,
#           "tv_heat_weight": 0.0
#         }
#       },
#       {
#         "timestamp": "2026-02-16T11:24:32.500936",
#         "thermal_time_constant": 21.596830826296134,
#         "heat_loss_coefficient": 0.5403259272501911,
#         "outlet_effectiveness": 0.4826476925561557,
#         "pv_heat_weight": 0.0001,
#         "tv_heat_weight": 0.19130751261040038,
#         "learning_rate": 0.04831530000000002,
#         "learning_confidence": 4.831530000000002,
#         "avg_recent_error": 0.030000000000000072,
#         "gradients": {
#           "thermal": 4.2610761394278816e-05,
#           "heat_loss_coefficient": -0.008746616283761895,
#           "outlet_effectiveness": 0.0,
#           "pv_heat_weight": 0.701008826631079,
#           "tv_heat_weight": 0.0
#         },
#         "changes": {
#           "thermal": 2.0587517184367243e-06,
#           "heat_loss_coefficient": 0.0004225953897348811,
#           "outlet_effectiveness": 0.0,
#           "pv_heat_weight": 0.0,
#           "tv_heat_weight": 0.0
#         }
#       },
#       {
#         "timestamp": "2026-02-16T11:51:32.924760",
#         "thermal_time_constant": 21.596829931144384,
#         "heat_loss_coefficient": 0.5402976554133823,
#         "outlet_effectiveness": 0.4826476925561557,
#         "pv_heat_weight": 0.0001,
#         "tv_heat_weight": 0.19130751261040038,
#         "learning_rate": 0.05,
#         "learning_confidence": 5.0,
#         "avg_recent_error": 0.020000000000000285,
#         "gradients": {
#           "thermal": 1.7903035033546544e-05,
#           "heat_loss_coefficient": 0.000565436736177824,
#           "outlet_effectiveness": 0.0,
#           "pv_heat_weight": 0.038924414345587445,
#           "tv_heat_weight": 0.0
#         },
#         "changes": {
#           "thermal": 8.951517500577211e-07,
#           "heat_loss_coefficient": 2.8271836808868578e-05,
#           "outlet_effectiveness": 0.0,
#           "pv_heat_weight": 0.0,
#           "tv_heat_weight": 0.0
#         }
#       },
#       {
#         "timestamp": "2026-02-16T12:08:33.275945",
#         "thermal_time_constant": 21.59683006540951,
#         "heat_loss_coefficient": 0.5398480823890854,
#         "outlet_effectiveness": 0.4826476925561557,
#         "pv_heat_weight": 0.005,
#         "tv_heat_weight": 0.19130751261040038,
#         "learning_rate": 0.05,
#         "learning_confidence": 5.0,
#         "avg_recent_error": 0.030000000000000426,
#         "gradients": {
#           "thermal": -2.6853025102458275e-06,
#           "heat_loss_coefficient": 0.008991460485937481,
#           "outlet_effectiveness": 0.0,
#           "pv_heat_weight": -0.5525946704287045,
#           "tv_heat_weight": 0.0
#         },
#         "changes": {
#           "thermal": 1.3426512524006284e-07,
#           "heat_loss_coefficient": 0.0004495730242968232,
#           "outlet_effectiveness": 0.0,
#           "pv_heat_weight": 0.0049,
#           "tv_heat_weight": 0.0
#         }
#       },
#       {
#         "timestamp": "2026-02-16T12:42:33.783601",
#         "thermal_time_constant": 21.5968245340829,
#         "heat_loss_coefficient": 0.5387059204906859,
#         "outlet_effectiveness": 0.4826476925561557,
#         "pv_heat_weight": 0.005,
#         "tv_heat_weight": 0.19130751261040038,
#         "learning_rate": 0.05,
#         "learning_confidence": 5.0,
#         "avg_recent_error": 0.040000000000000216,
#         "gradients": {
#           "thermal": 0.00011062653225051933,
#           "heat_loss_coefficient": 0.02284323796799016,
#           "outlet_effectiveness": 0.0,
#           "pv_heat_weight": -0.9311127424365393,
#           "tv_heat_weight": 0.0
#         },
#         "changes": {
#           "thermal": 5.531326610963561e-06,
#           "heat_loss_coefficient": 0.0011421618983995518,
#           "outlet_effectiveness": 0.0,
#           "pv_heat_weight": 0.0,
#           "tv_heat_weight": 0.0
#         }
#       },
#       {
#         "timestamp": "2026-02-16T12:42:33.929073",
#         "thermal_time_constant": 21.596819516924633,
#         "heat_loss_coefficient": 0.5371162134812022,
#         "outlet_effectiveness": 0.4826476925561557,
#         "pv_heat_weight": 0.005,
#         "tv_heat_weight": 0.19130751261040038,
#         "learning_rate": 0.05,
#         "learning_confidence": 5.0,
#         "avg_recent_error": 0.05,
#         "gradients": {
#           "thermal": 0.00010034316531879251,
#           "heat_loss_coefficient": 0.031794140189674455,
#           "outlet_effectiveness": 0.0,
#           "pv_heat_weight": -1.3119466596430402,
#           "tv_heat_weight": 0.0
#         },
#         "changes": {
#           "thermal": 5.017158265729904e-06,
#           "heat_loss_coefficient": 0.0015897070094836874,
#           "outlet_effectiveness": 0.0,
#           "pv_heat_weight": 0.0,
#           "tv_heat_weight": 0.0
#         }
#       }
#     ]
#   },
#   "prediction_metrics": {
#     "total_predictions": 114,
#     "accuracy_stats": {
#       "mae_1h": 0.0,
#       "mae_6h": 0.0,
#       "mae_24h": 0.0,
#       "mae_all_time": 0.0,
#       "rmse_all_time": 0.0
#     },
#     "recent_performance": {
#       "last_10_mae": 0.0,
#       "last_10_max_error": 0.0
#     }
#   },
#   "operational_state": {
#     "last_indoor_temp": 21.2,
#     "last_outdoor_temp": null,
#     "last_outlet_temp": null,
#     "last_prediction": null,
#     "last_run_time": "2026-02-16T12:42:34.024779",
#     "is_calibrating": false,
#     "last_run_features": {
#       "outlet_temp": 39.2,
#       "indoor_temp_lag_30m": 21.2,
#       "target_temp": 21.2,
#       "outdoor_temp": -0.4857142857142857,
#       "dhw_heating": 0.0,
#       "dhw_disinfection": 0.0,
#       "dhw_boost_heater": 0.0,
#       "defrosting": 0.0,
#       "pv_now": 695.5,
#       "fireplace_on": 0.0,
#       "tv_on": 0.0,
#       "temp_forecast_1h": -0.49,
#       "temp_forecast_2h": -0.69,
#       "temp_forecast_3h": -0.39,
#       "temp_forecast_4h": -0.09,
#       "pv_forecast_1h": 940.2,
#       "pv_forecast_2h": 396.0,
#       "pv_forecast_3h": 16.0,
#       "pv_forecast_4h": 0.0,
#       "temp_diff_indoor_outdoor": 21.631868131868128,
#       "indoor_temp_gradient": -0.3230769230769326,
#       "outlet_indoor_diff": 18.05384615384616,
#       "indoor_temp_lag_10m": 21.2,
#       "indoor_temp_lag_60m": 21.2,
#       "outlet_temp_lag_30m": 44.975,
#       "outlet_temp_change": 1.06666666666667,
#       "indoor_temp_delta_10m": -0.05384615384615543,
#       "indoor_temp_delta_30m": -0.05384615384615543,
#       "indoor_temp_delta_60m": -0.05384615384615543,
#       "hour_sin": 1.2246467991473532e-16,
#       "hour_cos": -1.0,
#       "month_sin": 0.49999999999999994,
#       "month_cos": 0.8660254037844387,
#       "outlet_effectiveness_ratio": -0.0029825308904985956,
#       "inlet_temp": 39.2,
#       "flow_rate": 30.1,
#       "power_consumption": 1573.94,
#       "delta_t": 0.0,
#       "thermal_power_kw": 0.0,
#       "cop_realtime": 0.0,
#       "temp_trend_forecast": 0.09892857142857142,
#       "heating_demand_forecast": 2.109,
#       "combined_forecast_thermal_load": 2.109
#     },
#     "last_final_temp": 42.6875,
#     "last_avg_other_rooms_temp": 19.75,
#     "last_fireplace_on": null,
#     "last_is_blocking": false,
#     "last_blocking_reasons": [],
#     "last_blocking_end_time": null
#   }
# }

# %% [markdown]
# ## 2. Parameter Drift Analysis
# Analyze how model parameters have evolved over time. (Requires historical parameter logging, which we simulate here by checking current values against defaults).

# %%
# Compare current parameters with defaults
default_params = {
    'heat_loss_coefficient': 0.5,
    'thermal_mass': 1000.0,
    'efficiency': 0.9
}

# current_state is a dict, not an object
# We need to extract parameters from the computed parameters
computed_params = state_manager.get_computed_parameters()

drift_data = []
for key, default_val in default_params.items():
    current_val = computed_params.get(key, default_val)
    drift = current_val - default_val
    drift_pct = (drift / default_val) * 100 if default_val != 0 else 0
    
    drift_data.append({
        'parameter': key,
        'default': default_val,
        'current': current_val,
        'drift_abs': drift,
        'drift_pct': drift_pct
    })
    
drift_df = pd.DataFrame(drift_data)
print("Parameter Drift Analysis:")
print(drift_df)
# Out:
# Parameter Drift Analysis:
#                parameter  default      current  drift_abs  drift_pct
# 0  heat_loss_coefficient      0.5     0.537144   0.037144   7.428897
# 1           thermal_mass   1000.0  1000.000000   0.000000   0.000000
# 2             efficiency      0.9     0.900000   0.000000   0.000000

# %% [markdown]
# ## 3. Learning Confidence
# Check the confidence levels of the learned parameters.

# %%
# Visualize Confidence
# In the unified state, confidence is a single global value, not per-parameter
learning_confidence = current_state.get('learning_state', {}).get('learning_confidence', 3.0)

print(f"Global Learning Confidence: {learning_confidence:.2f}")

# We can visualize this as a gauge or single bar
plt.figure(figsize=(6, 4))
plt.bar(['Global Confidence'], [learning_confidence], color='green' if learning_confidence > 2.0 else 'orange')
plt.title('Learning Confidence Score')
plt.ylabel('Confidence (Arbitrary Scale)')
plt.ylim(0, 5.0) # Assuming 5.0 is max reasonable confidence
plt.show()
# Out:
# Global Learning Confidence: 5.00

# %% [markdown]
# ## 4. Health Alerts
# Check for any critical issues or anomalies.

# %%
alerts = []

# Check for low confidence
if learning_confidence < 1.0:
    alerts.append(f"Low global learning confidence: {learning_confidence:.2f}")

# Check for extreme drift
for _, row in drift_df.iterrows():
    if abs(row['drift_pct']) > 50:
        alerts.append(f"High drift for {row['parameter']}: {row['drift_pct']:.1f}%")

if alerts:
    print("⚠️ Health Alerts:")
    for alert in alerts:
        print(f"- {alert}")
else:
    print("✅ System Health: OK")
# Out:
# ✅ System Health: OK

# %% [markdown]
# ## 5. Conclusions
# Summarize health status here.
